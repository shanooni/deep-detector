# %%
import numpy as np
from lazypredict.Supervised import LazyClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
import pandas as pd

# %%
inputs = np.load("extracted_features/resnet_features.npy")
labels = np.load("extracted_features/resnet_labels.npy")

# %%
X_train, X_test, y_train, y_test = train_test_split(inputs, labels, test_size=0.25, random_state=42)

# %%
classifier = LazyClassifier(verbose=0, ignore_warnings=True, custom_metric=None)

# %%
models, predictions = classifier.fit(X_train, X_test, y_train, y_test)
# Out:
#   0%|          | 0/32 [00:00<?, ?it/s]
# [LightGBM] [Info] Number of positive: 3778, number of negative: 3720
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.008152 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 130560
# [LightGBM] [Info] Number of data points in the train set: 7498, number of used features: 512
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.503868 -> initscore=0.015471
# [LightGBM] [Info] Start training from score 0.015471

# %%
print("\n🏁 Model Comparison Results:")
print(models)
# Out:
# 🏁 Model Comparison Results:
#                                Accuracy  Balanced Accuracy  ROC AUC  F1 Score  \
# Model
# NuSVC                              0.78               0.78     0.78      0.78
# CalibratedClassifierCV             0.78               0.78     0.78      0.78
# LinearDiscriminantAnalysis         0.78               0.78     0.78      0.78
# RidgeClassifier                    0.78               0.78     0.78      0.78
# LinearSVC                          0.78               0.78     0.78      0.78
# RidgeClassifierCV                  0.78               0.78     0.78      0.78
# LogisticRegression                 0.78               0.78     0.78      0.78
# SVC                                0.78               0.78     0.78      0.77
# XGBClassifier                      0.75               0.75     0.75      0.75
# LGBMClassifier                     0.75               0.75     0.75      0.75
# Perceptron                         0.74               0.74     0.74      0.74
# SGDClassifier                      0.73               0.73     0.73      0.73
# RandomForestClassifier             0.73               0.73     0.73      0.73
# ExtraTreesClassifier               0.72               0.72     0.72      0.72
# QuadraticDiscriminantAnalysis      0.72               0.72     0.72      0.72
# AdaBoostClassifier                 0.71               0.71     0.71      0.71
# PassiveAggressiveClassifier        0.71               0.71     0.71      0.71
# GaussianNB                         0.69               0.69     0.69      0.69
# NearestCentroid                    0.69               0.69     0.69      0.69
# BernoulliNB                        0.69               0.69     0.69      0.69
# KNeighborsClassifier               0.68               0.68     0.68      0.68
# BaggingClassifier                  0.67               0.67     0.67      0.67
# DecisionTreeClassifier             0.63               0.63     0.63      0.63
# ExtraTreeClassifier                0.57               0.57     0.57      0.57
# LabelSpreading                     0.52               0.51     0.51      0.37
# LabelPropagation                   0.52               0.51     0.51      0.37
# DummyClassifier                    0.49               0.50     0.50      0.32
#
#                                Time Taken
# Model
# NuSVC                               12.64
# CalibratedClassifierCV               4.00
# LinearDiscriminantAnalysis           0.25
# RidgeClassifier                      0.09
# LinearSVC                            1.00
# RidgeClassifierCV                    0.41
# LogisticRegression                   0.25
# SVC                                 10.86
# XGBClassifier                        2.73
# LGBMClassifier                       1.70
# Perceptron                           0.10
# SGDClassifier                        0.84
# RandomForestClassifier              10.12
# ExtraTreesClassifier                 1.84
# QuadraticDiscriminantAnalysis        0.41
# AdaBoostClassifier                  18.69
# PassiveAggressiveClassifier          0.20
# GaussianNB                           0.09
# NearestCentroid                      0.08
# BernoulliNB                          0.14
# KNeighborsClassifier                 0.26
# BaggingClassifier                   27.19
# DecisionTreeClassifier               4.45
# ExtraTreeClassifier                  0.08
# LabelSpreading                       1.06
# LabelPropagation                     1.19
# DummyClassifier                      0.07

# %%
# Save the model performance summary
models.to_csv("outputs/lazyclassifier_results.csv", index=True)
print("✅ Results saved to outputs/lazyclassifier_results.csv")
# Out:
# ✅ Results saved to outputs/lazyclassifier_results.csv
