# %%
import numpy as np
from lazypredict.Supervised import LazyClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
import pandas as pd

# %%
inputs = np.load("extracted_features/resnet152_features.npy")
labels = np.load("extracted_features/resnet152_labels.npy")

# %%
X_train, X_test, y_train, y_test = train_test_split(inputs, labels, test_size=0.25, random_state=42)

# %%
classifier = LazyClassifier(verbose=0, ignore_warnings=True, custom_metric=None)

# %%
models, predictions = classifier.fit(X_train, X_test, y_train, y_test)
# Out:
#   0%|          | 0/32 [00:00<?, ?it/s]
# [LightGBM] [Info] Number of positive: 3778, number of negative: 3720
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.070776 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 522240
# [LightGBM] [Info] Number of data points in the train set: 7498, number of used features: 2048
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.503868 -> initscore=0.015471
# [LightGBM] [Info] Start training from score 0.015471

# %%
print("\n🏁 Model Comparison Results:")
print(models)
# Out:
# 🏁 Model Comparison Results:
#                                Accuracy  Balanced Accuracy  ROC AUC  F1 Score  \
# Model
# NuSVC                              0.78               0.78     0.78      0.78
# SVC                                0.77               0.77     0.77      0.77
# RidgeClassifier                    0.77               0.77     0.77      0.77
# RidgeClassifierCV                  0.77               0.77     0.77      0.77
# LinearDiscriminantAnalysis         0.77               0.77     0.77      0.77
# PassiveAggressiveClassifier        0.76               0.76     0.76      0.76
# Perceptron                         0.76               0.76     0.76      0.76
# LogisticRegression                 0.76               0.76     0.76      0.76
# CalibratedClassifierCV             0.76               0.76     0.76      0.76
# LGBMClassifier                     0.74               0.74     0.74      0.74
# SGDClassifier                      0.74               0.74     0.74      0.74
# XGBClassifier                      0.74               0.74     0.74      0.74
# LinearSVC                          0.73               0.73     0.73      0.73
# RandomForestClassifier             0.72               0.72     0.72      0.72
# QuadraticDiscriminantAnalysis      0.71               0.72     0.72      0.71
# ExtraTreesClassifier               0.71               0.71     0.71      0.71
# AdaBoostClassifier                 0.70               0.70     0.70      0.70
# NearestCentroid                    0.68               0.68     0.68      0.68
# BernoulliNB                        0.68               0.68     0.68      0.68
# GaussianNB                         0.68               0.68     0.68      0.67
# BaggingClassifier                  0.66               0.66     0.66      0.66
# KNeighborsClassifier               0.65               0.65     0.65      0.65
# DecisionTreeClassifier             0.61               0.61     0.61      0.61
# ExtraTreeClassifier                0.59               0.59     0.59      0.59
# LabelSpreading                     0.52               0.51     0.51      0.37
# LabelPropagation                   0.52               0.51     0.51      0.37
# DummyClassifier                    0.49               0.50     0.50      0.32
#
#                                Time Taken
# Model
# NuSVC                               39.89
# SVC                                 35.32
# RidgeClassifier                      0.39
# RidgeClassifierCV                    5.63
# LinearDiscriminantAnalysis           2.67
# PassiveAggressiveClassifier          1.97
# Perceptron                           1.08
# LogisticRegression                   1.17
# CalibratedClassifierCV             435.76
# LGBMClassifier                       6.17
# SGDClassifier                        2.38
# XGBClassifier                       11.72
# LinearSVC                           28.57
# RandomForestClassifier              21.82
# QuadraticDiscriminantAnalysis       11.20
# ExtraTreesClassifier                 3.93
# AdaBoostClassifier                  74.51
# NearestCentroid                      0.34
# BernoulliNB                          0.51
# GaussianNB                           0.37
# BaggingClassifier                  124.66
# KNeighborsClassifier                 1.09
# DecisionTreeClassifier              22.05
# ExtraTreeClassifier                  0.28
# LabelSpreading                       3.84
# LabelPropagation                     2.42
# DummyClassifier                      0.24

# %%
# Save the model performance summary
models.to_csv("outputs/resnet152_lazyclassifier_results.csv", index=True)
print("✅ Results saved to outputs/resnet152_lazyclassifier_results.csv")
# Out:
# ✅ Results saved to outputs/resnet152_lazyclassifier_results.csv
