# %%
import numpy as np
from lazypredict.Supervised import LazyClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
import pandas as pd

# %%
inputs = np.load("extracted_features/resnet101_features.npy")
labels = np.load("extracted_features/resnet101_labels.npy")

# %%
X_train, X_test, y_train, y_test = train_test_split(inputs, labels, test_size=0.25, random_state=42)

# %%
classifier = LazyClassifier(verbose=0, ignore_warnings=True, custom_metric=None)

# %%
models, predictions = classifier.fit(X_train, X_test, y_train, y_test)
# Out:
#   0%|          | 0/32 [00:00<?, ?it/s]
# [LightGBM] [Info] Number of positive: 3778, number of negative: 3720
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.070324 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 522240
# [LightGBM] [Info] Number of data points in the train set: 7498, number of used features: 2048
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.503868 -> initscore=0.015471
# [LightGBM] [Info] Start training from score 0.015471

# %%
print("\n🏁 Model Comparison Results:")
print(models)
# Out:
# 🏁 Model Comparison Results:
#                                Accuracy  Balanced Accuracy  ROC AUC  F1 Score  \
# Model
# NuSVC                              0.79               0.79     0.79      0.79
# LogisticRegression                 0.78               0.78     0.78      0.78
# SVC                                0.78               0.78     0.78      0.78
# RidgeClassifier                    0.78               0.78     0.78      0.78
# LinearDiscriminantAnalysis         0.78               0.78     0.78      0.78
# RidgeClassifierCV                  0.78               0.78     0.78      0.78
# CalibratedClassifierCV             0.77               0.77     0.77      0.77
# Perceptron                         0.77               0.77     0.77      0.77
# PassiveAggressiveClassifier        0.77               0.77     0.77      0.77
# LGBMClassifier                     0.76               0.76     0.76      0.76
# LinearSVC                          0.76               0.76     0.76      0.76
# SGDClassifier                      0.75               0.75     0.75      0.75
# XGBClassifier                      0.75               0.75     0.75      0.75
# RandomForestClassifier             0.74               0.74     0.74      0.74
# AdaBoostClassifier                 0.72               0.73     0.73      0.72
# ExtraTreesClassifier               0.72               0.72     0.72      0.72
# QuadraticDiscriminantAnalysis      0.72               0.72     0.72      0.72
# NearestCentroid                    0.69               0.69     0.69      0.69
# BaggingClassifier                  0.69               0.69     0.69      0.69
# GaussianNB                         0.68               0.68     0.68      0.68
# BernoulliNB                        0.68               0.68     0.68      0.68
# KNeighborsClassifier               0.67               0.67     0.67      0.67
# DecisionTreeClassifier             0.63               0.63     0.63      0.63
# ExtraTreeClassifier                0.59               0.59     0.59      0.59
# LabelSpreading                     0.52               0.51     0.51      0.37
# LabelPropagation                   0.52               0.51     0.51      0.37
# DummyClassifier                    0.49               0.50     0.50      0.32
#
#                                Time Taken
# Model
# NuSVC                               40.70
# LogisticRegression                   1.19
# SVC                                 35.07
# RidgeClassifier                      0.39
# LinearDiscriminantAnalysis           2.56
# RidgeClassifierCV                    5.60
# CalibratedClassifierCV             479.15
# Perceptron                           0.76
# PassiveAggressiveClassifier          2.36
# LGBMClassifier                       6.19
# LinearSVC                           56.57
# SGDClassifier                        2.92
# XGBClassifier                       12.50
# RandomForestClassifier              22.20
# AdaBoostClassifier                  75.04
# ExtraTreesClassifier                 3.91
# QuadraticDiscriminantAnalysis       11.39
# NearestCentroid                      0.35
# BaggingClassifier                  144.93
# GaussianNB                           0.32
# BernoulliNB                          0.54
# KNeighborsClassifier                 0.95
# DecisionTreeClassifier              18.62
# ExtraTreeClassifier                  0.28
# LabelSpreading                       2.22
# LabelPropagation                     2.10
# DummyClassifier                      0.27

# %%
# Save the model performance summary
models.to_csv("outputs/resnet101_lazyclassifier_results.csv", index=True)
print("✅ Results saved to outputs/resnet101_lazyclassifier_results.csv")
# Out:
# ✅ Results saved to outputs/resnet101_lazyclassifier_results.csv
