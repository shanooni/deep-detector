# %%
import numpy as np
from lazypredict.Supervised import LazyClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
import pandas as pd

# %%
inputs = np.load("extracted_features/resnet50_features.npy")
labels = np.load("extracted_features/resnet50_labels.npy")

# %%
X_train, X_test, y_train, y_test = train_test_split(inputs, labels, test_size=0.25, random_state=42)

# %%
classifier = LazyClassifier(verbose=0, ignore_warnings=True, custom_metric=None)

# %%
models, predictions = classifier.fit(X_train, X_test, y_train, y_test)
# Out:
#   0%|          | 0/32 [00:00<?, ?it/s]
# [LightGBM] [Info] Number of positive: 3778, number of negative: 3720
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.073897 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 522240
# [LightGBM] [Info] Number of data points in the train set: 7498, number of used features: 2048
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.503868 -> initscore=0.015471
# [LightGBM] [Info] Start training from score 0.015471

# %%
print("\n🏁 Model Comparison Results:")
print(models)
# Out:
# 🏁 Model Comparison Results:
#                                Accuracy  Balanced Accuracy  ROC AUC  F1 Score  \
# Model
# NuSVC                              0.79               0.79     0.79      0.79
# SVC                                0.78               0.78     0.78      0.78
# RidgeClassifierCV                  0.78               0.78     0.78      0.78
# LinearDiscriminantAnalysis         0.78               0.78     0.78      0.78
# RidgeClassifier                    0.78               0.78     0.78      0.78
# LogisticRegression                 0.78               0.78     0.78      0.78
# PassiveAggressiveClassifier        0.78               0.78     0.78      0.78
# SGDClassifier                      0.77               0.77     0.77      0.77
# CalibratedClassifierCV             0.77               0.77     0.77      0.77
# LGBMClassifier                     0.77               0.77     0.77      0.77
# XGBClassifier                      0.76               0.76     0.76      0.76
# Perceptron                         0.75               0.75     0.75      0.75
# LinearSVC                          0.74               0.74     0.74      0.74
# AdaBoostClassifier                 0.73               0.73     0.73      0.73
# ExtraTreesClassifier               0.73               0.73     0.73      0.73
# RandomForestClassifier             0.72               0.73     0.73      0.72
# QuadraticDiscriminantAnalysis      0.72               0.72     0.72      0.71
# NearestCentroid                    0.70               0.70     0.70      0.70
# BaggingClassifier                  0.70               0.70     0.70      0.70
# GaussianNB                         0.69               0.70     0.70      0.69
# BernoulliNB                        0.69               0.69     0.69      0.69
# KNeighborsClassifier               0.69               0.69     0.69      0.69
# DecisionTreeClassifier             0.63               0.63     0.63      0.63
# ExtraTreeClassifier                0.59               0.59     0.59      0.59
# LabelSpreading                     0.52               0.51     0.51      0.37
# LabelPropagation                   0.52               0.51     0.51      0.37
# DummyClassifier                    0.49               0.50     0.50      0.32
#
#                                Time Taken
# Model
# NuSVC                               39.56
# SVC                                 34.77
# RidgeClassifierCV                    5.85
# LinearDiscriminantAnalysis           2.43
# RidgeClassifier                      0.41
# LogisticRegression                   1.25
# PassiveAggressiveClassifier          2.98
# SGDClassifier                        1.88
# CalibratedClassifierCV             448.61
# LGBMClassifier                       6.16
# XGBClassifier                       11.97
# Perceptron                           1.00
# LinearSVC                           35.41
# AdaBoostClassifier                  77.19
# ExtraTreesClassifier                 3.88
# RandomForestClassifier              22.12
# QuadraticDiscriminantAnalysis       11.59
# NearestCentroid                      0.32
# BaggingClassifier                  136.48
# GaussianNB                           0.33
# BernoulliNB                          0.51
# KNeighborsClassifier                 1.02
# DecisionTreeClassifier              18.17
# ExtraTreeClassifier                  0.29
# LabelSpreading                       2.15
# LabelPropagation                     2.11
# DummyClassifier                      0.29

# %%
# Save the model performance summary
models.to_csv("outputs/resnet50_lazyclassifier_results.csv", index=True)
print("✅ Results saved to outputs/resnet50_lazyclassifier_results.csv")
# Out:
# ✅ Results saved to outputs/resnet50_lazyclassifier_results.csv
