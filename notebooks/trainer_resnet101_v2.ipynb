# %%
import numpy as np
from lazypredict.Supervised import LazyClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
import pandas as pd

# %%
inputs = np.load("extracted_features/resnet101_v2_features.npy")
labels = np.load("extracted_features/resnet101_v2_labels.npy")

# %%
X_train, X_test, y_train, y_test = train_test_split(inputs, labels, test_size=0.25, random_state=42)

# %%
classifier = LazyClassifier(verbose=0, ignore_warnings=True, custom_metric=None)

# %%
models, predictions = classifier.fit(X_train, X_test, y_train, y_test)
# Out:
#   0%|          | 0/32 [00:00<?, ?it/s]
# [LightGBM] [Info] Number of positive: 3778, number of negative: 3720
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.086436 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 522120
# [LightGBM] [Info] Number of data points in the train set: 7498, number of used features: 2048
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.503868 -> initscore=0.015471
# [LightGBM] [Info] Start training from score 0.015471

# %%
print("\n🏁 Model Comparison Results:")
print(models)
# Out:
# 🏁 Model Comparison Results:
#                                Accuracy  Balanced Accuracy  ROC AUC  F1 Score  \
# Model
# LGBMClassifier                     0.78               0.78     0.78      0.78
# XGBClassifier                      0.78               0.78     0.78      0.78
# NuSVC                              0.77               0.78     0.78      0.77
# SVC                                0.77               0.77     0.77      0.77
# AdaBoostClassifier                 0.75               0.75     0.75      0.75
# RidgeClassifier                    0.75               0.75     0.75      0.75
# LinearDiscriminantAnalysis         0.75               0.75     0.75      0.75
# RidgeClassifierCV                  0.75               0.75     0.75      0.75
# CalibratedClassifierCV             0.74               0.74     0.74      0.74
# LogisticRegression                 0.74               0.74     0.74      0.74
# RandomForestClassifier             0.73               0.73     0.73      0.73
# LinearSVC                          0.73               0.73     0.73      0.73
# PassiveAggressiveClassifier        0.73               0.73     0.73      0.73
# Perceptron                         0.72               0.72     0.72      0.72
# SGDClassifier                      0.72               0.72     0.72      0.72
# ExtraTreesClassifier               0.71               0.72     0.72      0.71
# BernoulliNB                        0.70               0.70     0.70      0.70
# NearestCentroid                    0.70               0.70     0.70      0.70
# QuadraticDiscriminantAnalysis      0.69               0.70     0.70      0.69
# BaggingClassifier                  0.69               0.69     0.69      0.69
# GaussianNB                         0.67               0.67     0.67      0.67
# KNeighborsClassifier               0.64               0.64     0.64      0.63
# DecisionTreeClassifier             0.63               0.64     0.64      0.63
# ExtraTreeClassifier                0.58               0.58     0.58      0.58
# LabelSpreading                     0.52               0.51     0.51      0.37
# LabelPropagation                   0.52               0.51     0.51      0.37
# DummyClassifier                    0.49               0.50     0.50      0.32
#
#                                Time Taken
# Model
# LGBMClassifier                      10.57
# XGBClassifier                       14.53
# NuSVC                               61.73
# SVC                                 50.48
# AdaBoostClassifier                  47.79
# RidgeClassifier                      0.70
# LinearDiscriminantAnalysis           4.68
# RidgeClassifierCV                    9.28
# CalibratedClassifierCV             476.58
# LogisticRegression                   1.95
# RandomForestClassifier              15.53
# LinearSVC                           10.88
# PassiveAggressiveClassifier          1.88
# Perceptron                           1.33
# SGDClassifier                        3.30
# ExtraTreesClassifier                 5.21
# BernoulliNB                          0.65
# NearestCentroid                      0.57
# QuadraticDiscriminantAnalysis       16.15
# BaggingClassifier                   81.27
# GaussianNB                           0.54
# KNeighborsClassifier                 1.29
# DecisionTreeClassifier              13.08
# ExtraTreeClassifier                  0.41
# LabelSpreading                       3.30
# LabelPropagation                     2.99
# DummyClassifier                      0.43

# %%
# Save the model performance summary
models.to_csv("outputs/resnet101_v2_lazyclassifier_results.csv", index=True)
print("✅ Results saved to outputs/resnet101_v2_lazyclassifier_results.csv")
# Out:
# ✅ Results saved to outputs/resnet101_v2_lazyclassifier_results.csv
